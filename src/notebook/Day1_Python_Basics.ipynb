# %% [markdown]
# # Day 1: Python Basics - Print and Input
#
# Welcome to Day 1 of our Python Crash Course. In this notebook, you will learn how to display information with `print()` and get user input with `input()`.

# %% [markdown]
# ## Learning Objectives
# - Understand how to use `print()` to display messages.
# - Learn how to accept input from the user with `input()`.
# - Practice combining strings and user input.
# - Get familiar with basic Python syntax.

# %% [markdown]
# ## Instructions for the Notebook
# 1. Read each section carefully.
# 2. Try running the code in each cell.
# 3. Modify the code in practice cells to explore Python.
# 4. Submit your completed exercises in the community platform if available.

# %%
# Example: Displaying a message
print("Hello, Python!")

# %% [markdown]
# ## Practice 1: Printing your name

# %%
# Try printing your name
print("Your Name Here")

# %% [markdown]
# ## Example: Getting user input

# %%
# Ask for user's name
name = input("Enter your name: ")
print("Hello, " + name + "! Welcome to Python.")

# %% [markdown]
# ## Practice 2: Ask user for favorite color

# %%
# Ask user for favorite color and print a response
color = input("What's your favorite color? ")
print("Wow, I like " + color + " too!")

# %% [markdown]
# ## Challenge: Combine input and print

# %%
# Ask user for name and age and greet them
name = input("Enter your name: ")
age = input("Enter your age: ")
print(f"Hello {name}, you are {age} years old!")

# %% [markdown]
# ### Next Steps
# Once you finish these exercises, you'll be ready for Day 2, where we'll explore variables, data types, and simple arithmetic operations.
